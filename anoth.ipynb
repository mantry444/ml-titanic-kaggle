# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
file= pd.read_csv('/home/rk/ML/titan/titanic/train.csv')
file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t=pd.crosstab(file.Pclass,file.Survived)
t
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
p1= t.plot(kind= 'bar',stacked= True)

# %%
sns.factorplot( 'Pclass', 'Survived', hue= 'Sex', data=file)
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/rk/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Pclass', 'Survived',hue= 'Sex', col= 'Embarked', data= file )
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/rk/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab(file.Embarked, file.Survived)
sns.barplot(file.Embarked, file.Survived)
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Embarked', ylabel='Survived'>

# %%
t1=pd.crosstab(file.Parch, file.Survived)
t1.describe()
# Out:
# Survived           0           1
# count       7.000000    7.000000
# mean       78.428571   48.857143
# std       162.999854   85.063562
# min         1.000000    0.000000
# 25%         3.000000    0.500000
# 50%         4.000000    3.000000
# 75%        46.500000   52.500000
# max       445.000000  233.000000

# %%
sns.barplot(file.Parch, file.Survived)
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Parch', ylabel='Survived'>

# %%
sns.barplot(file.SibSp, file.Survived)
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %%
sns.violinplot(x=file.Sex, y= file.Age, hue=file.Survived, split=True)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(file.Sex, file.Age, file.Survived, split= True)
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(  file.Pclass, file.Age, file.Survived, split= False)
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.violinplot(file.Embarked, file.Age, file.Survived, split= False)
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Embarked', ylabel='Age'>

# %%
female_survived= file[(file.Survived==1) &(file.Sex=='female') ]
female_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
female_survived = file[(file['Survived']==1) & (file['Sex']=="female")]
female_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.displot(female_survived.Age.dropna(), bins=range (0,64,1), color= 'violet')

# %%
female_died=file[(file.Survived==0) & (file.Sex == 'female')]
female_died
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.distplot(female_died.Age.dropna().values,bins=range(0,81,1), kde= False, color= 'red')
sns.distplot(female_survived.Age.dropna().values, bins=range (0,81,1), kde= False, color= 'blue')
# Out:
# /home/rk/.local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
#plt.subplot(121)
sns.distplot(female_survived.Age.dropna().values, bins=range(0, 81, 1), kde=False, color='blue')
sns.distplot(female_died.Age.dropna().values, bins=range(0, 81, 1), kde=False, color='red')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(file.drop('PassengerId', axis=1).corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
p=pd.get_dummies(file, columns=['Sex', 'Embarked'])
file1=p
file1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Sex_female   891 non-null    uint8
#  11  Sex_male     891 non-null    uint8
#  12  Embarked_C   891 non-null    uint8
#  13  Embarked_Q   891 non-null    uint8
#  14  Embarked_S   891 non-null    uint8
# dtypes: float64(2), int64(5), object(3), uint8(5)
# memory usage: 74.1+ KB

# %%
file1.pop('Cabin')
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
file1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
from sklearn.ensemble import RandomForestClassifier 
features= ['Pclass','SibSp','Parch','Fare','Sex_female','Sex_male','Embarked_C', 'Embarked_S','Embarked_Q']
X=file1[features]
X
# Out:
#      Pclass  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0         3      1      0   7.2500           0         1           0
# 1         1      1      0  71.2833           1         0           1
# 2         3      0      0   7.9250           1         0           0
# 3         1      1      0  53.1000           1         0           0
# 4         3      0      0   8.0500           0         1           0
# ..      ...    ...    ...      ...         ...       ...         ...
# 886       2      0      0  13.0000           0         1           0
# 887       1      0      0  30.0000           1         0           0
# 888       3      1      2  23.4500           1         0           0
# 889       1      0      0  30.0000           0         1           1
# 890       3      0      0   7.7500           0         1           0
#
#      Embarked_S  Embarked_Q
# 0             1           0
# 1             0           0
# 2             1           0
# ...

# %%
Y=file1['Survived']
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(X,Y,test_size=0.2)
model= RandomForestClassifier(n_estimators=1000,max_depth=10,n_jobs=-1 )
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=1000, n_jobs=-1)

# %%
model.base_estimator_
# Out:
# DecisionTreeClassifier()

# %%
predict=model.predict(x_test)

# %%
train_score=model.score(x_train,y_train)
train_score
# Out:
# 0.922752808988764

# %%
from  sklearn.metrics import accuracy_score
acuracy= accuracy_score(y_test, predict)
acuracy
# Out:
# 0.8044692737430168

# %%
# %%timeit
model= RandomForestClassifier(n_jobs=-1)
model.fit(x_train,y_train)
# Out:
# 169 ms ± 13.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
model= RandomForestClassifier(n_jobs=1)
model.fit(x_train,y_train)
# Out:
# 117 ms ± 7.95 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Acuracy without including age = 0.8

# %%
model= RandomForestClassifier(n_estimators=100)
model
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
para= {
    'n_estimators' : range(1,1000,10),
    'max_depth' : range(1,11,1),


}

# %%
model_grid= GridSearchCV(RandomForestClassifier(n_jobs=1),param_grid=para, cv=5)
model=(model_grid.fit(x_train, y_train))

# %%
model.best_estimator_
# Out:
# RandomForestClassifier(max_depth=6, n_estimators=261, n_jobs=1)

# %%
model= RandomForestClassifier(max_depth=6, n_estimators=261, n_jobs=-1)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, n_estimators=261, n_jobs=-1)

# %%
train_score= model.score(x_train,y_train)
train_score
# Out:
# 0.8623595505617978

# %%
predict= model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score= accuracy_score(y_test, predict)
accuracy_score
# Out:
# 0.8100558659217877

# %%
file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
